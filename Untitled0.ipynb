# %% [markdown]
# <a href="https://colab.research.google.com/github/drawcodeboy/Colab_Test/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
plt.plot([1, 3, 4])

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

plt.plot([1, 2, 3], [110, 130, 120])
plt.xlabel('test x')
plt.ylabel('test y')
plt.title('Test result')
plt.show()
